# %%
   class CalculoRecibo():
    
    @classmethod
    def dados_entrada(cls, valores_iniciais):
        valor = valores_iniciais['valor']
        valor_extenso = valores_iniciais['v_extenso']
        dt_inicio_contrato = valores_iniciais['data_inicio_contrato']
        dt_final_contrato = valores_iniciais['data_final_contrato']
        
        
        lista_recibos = []
        mes = 0
        for periodo in range(12):
            
            
            dados_recibo = {}
            
            if periodo == 0:
                dados_recibo['mes'] = periodo + 1
                dados_recibo['dt_vencimento'] = cls.soma_mes(dt_inicio_contrato, 0)
                dados_recibo['mes_referencia'] = cls.mes_referencia(dados_recibo['dt_vencimento'])
                dados_recibo['periodo_ref'] = cls.periodo_ref(dados_recibo['dt_vencimento'])
                
            else:
                mes = mes + 1
                dados_recibo['mes'] = mes + 1
                
                dados_recibo['dt_vencimento'] = cls.soma_mes(dt_inicio_contrato, mes)
                dados_recibo['mes_referencia'] = cls.mes_referencia(dados_recibo['dt_vencimento'], mes)
                dados_recibo['periodo_ref'] = cls.periodo_ref(dados_recibo['dt_vencimento'])
                
            dados_recibo['info_contrato'] = 'Inicio {} Vencimento {}'.format(dt_inicio_contrato, dt_final_contrato)
                
                
            
            lista_recibos.append(dados_recibo)
                
        return lista_recibos
                
                         
    @classmethod
    def soma_mes(cls, data, numero_mes):
        
        split = data.split('/')
        mes = int(split[1])
        mes = mes + numero_mes
        
        if mes > 12:
            ano = int(split[2])
            ano = ano + 1
            mes = mes - 12
            nova_data = split[0] + '/' + str(mes) + '/' + str(ano)
        else:
            nova_data = split[0] + '/' + str(mes) + '/' + split[2]
            
        return nova_data
    
    @classmethod
    def mes_referencia(cls, data, novo_mes=None):
        
        split = data.split('/')
        
        mes = int(split[1])
        ano = int(split[2])
        
        if novo_mes != None:
            if mes > 12:
                mes = mes - 12
                ano = ano + 1
            m_referencia = str(mes) + '/' + str(ano)
        else:
            m_referencia = split[1] + '/' + split[2]
        
        return m_referencia
    
    @classmethod
    def periodo_ref(cls, data_vencimento):
        
        split = data_vencimento.split('/')
        dia = int(split[0]) - 1
        mes = int(split[1]) + 1
        ano = int(split[2])
        
        
        if mes > 12:
            mes = mes - 12
            ano = ano + 1
        
        data_ref_final = "{}/{}/{}".format(str(dia), str(mes), str(ano))
        
        return "{} à {}".format(data_vencimento, data_ref_final)
                
    #Soma n aos meses sem alterar a             
    @classmethod
    def soma_mes(cls, data, numero_mes):
        
        split = data.split('/')
        mes = int(split[1])
        mes = mes + numero_mes
        
        if mes > 12:
            ano = int(split[2])
            ano = ano + 1
            mes = numero_mes
            nova_data = split[0] + '/' + str(mes) + '/' + str(ano)
        else:
            nova_data = split[0] + '/' + str(mes) + '/' + str(split[2])
            
        return nova_data
    
    @classmethod
    def mes_referencia(cls, data):
        
        split = data.split('/')
        
        m_referencia = split[1] + '/' + split[2]
        
        return m_referencia
    
    @classmethod
    def periodo_ref(cls, data_vencimento):
        
        split = data_vencimento.split('/')

# %%
dados_iniciais = {
    'valor': 100.00,
    'v_extenso': 'Cem reais',
    'data_inicio_contrato': '20/01/2023',
    'data_final_contrato':'19/01/2024'
}

# %%
resultado = CalculoRecibo().dados_entrada(dados_iniciais)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 resultado = CalculoRecibo().dados_entrada(dados_iniciais)
#
# Cell In[4], line 20, in CalculoRecibo.dados_entrada(cls, valores_iniciais)
#      18 if periodo == 0:
#      19     dados_recibo['mes'] = periodo + 1
# ---> 20     dados_recibo['dt_vencimento'] = cls.soma_mes(dt_inicio_contrato, 0)
#      21     dados_recibo['mes_referencia'] = cls.mes_referencia(dados_recibo['dt_vencimento'])
#      22     dados_recibo['periodo_ref'] = cls.periodo_ref(dados_recibo['dt_vencimento'])
#
# Cell In[4], line 107, in CalculoRecibo.soma_mes(cls, data, numero_mes)
#     105     nova_data = split[0] + '/' + mes + '/' + ano
#     106 else:
# --> 107     nova_data = split[0] + '/' + mes + '/' + split[2]
#     109 return nova_data
#
# TypeError: can only concatenate str (not "int") to str

# %%
for dados in resultado:
    print(dados)
